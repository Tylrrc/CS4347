# %%
! git clone https://github.com/Tylrrc/CS4347.git
# Out:
# Cloning into 'CS4347'...
# remote: Enumerating objects: 168, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 1449 (delta 59), reused 138 (delta 40), pack-reused 1281
# Receiving objects: 100% (1449/1449), 146.11 MiB | 30.30 MiB/s, done.
# Resolving deltas: 100% (111/111), done.
# Checking out files: 100% (1091/1091), done.

# %%
! pwd
# %cd CS4347/assign3_convolution_nn/data/
! unzip food101small.zip
# Out:
# /content
# /content/CS4347/assign3_convolution_nn/data
# Archive:  food101small.zip
#    creating: food101small/
#    creating: food101small/test/
#    creating: food101small/test/bread_pudding/
#   inflating: food101small/test/bread_pudding/25797.jpg
#   inflating: food101small/test/bread_pudding/3204923.jpg
#   inflating: food101small/test/bread_pudding/842501.jpg
#   inflating: food101small/test/bread_pudding/849064.jpg
#   inflating: food101small/test/bread_pudding/1856274.jpg
#   inflating: food101small/test/bread_pudding/1511978.jpg
#   inflating: food101small/test/bread_pudding/597597.jpg
#   inflating: food101small/test/bread_pudding/3772264.jpg
#   inflating: food101small/test/bread_pudding/533940.jpg
#   inflating: food101small/test/bread_pudding/1641217.jpg
#   inflating: food101small/test/bread_pudding/3039406.jpg
#   inflating: food101small/test/bread_pudding/2978061.jpg
#   inflating: food101small/test/bread_pudding/2371767.jpg
# ...

# %%
# %cd ..
# Out:
# /content/CS4347/assign3_convolution_nn

# %%
! python kerasmain101.py
# Out:
# Using TensorFlow backend.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %%
! python main101.py
# Out:
# TRAINING: 100% 1000/1000 [00:23<00:00, 42.30it/s, epoch=0, loss=2.3, accuracy=0]
# TESTING: 100% 10000/10000 [00:24<00:00, 403.32it/s, epoch=0, loss=2.3, accuracy=9.99]
# TRAINING: 100% 1000/1000 [00:23<00:00, 42.82it/s, epoch=1, loss=2.3, accuracy=0]
# TESTING: 100% 10000/10000 [00:24<00:00, 403.83it/s, epoch=1, loss=2.3, accuracy=9.99]
# TRAINING: 100% 1000/1000 [00:23<00:00, 42.39it/s, epoch=2, loss=2.3, accuracy=0]
# TESTING: 100% 10000/10000 [00:25<00:00, 398.67it/s, epoch=2, loss=2.3, accuracy=9.99]
# TRAINING: 100% 1000/1000 [00:23<00:00, 42.49it/s, epoch=3, loss=2.3, accuracy=0]
# TESTING: 100% 10000/10000 [00:24<00:00, 403.55it/s, epoch=3, loss=2.3, accuracy=9.98]
# TRAINING:   7% 69/1000 [00:01<00:22, 42.07it/s, epoch=4, loss=2.3, accuracy=0]Traceback (most recent call last):
#   File "main101.py", line 17, in <module>
#     htd.run()
#   File "/content/CS4347/assign3_convolution_nn/trainer/trainer101.py", line 145, in run
#     self.train(i)
# ...

# %%
! python kerasmain101withtrained.py
# Out:
# Using TensorFlow backend.
# Found 10000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ...
